# %% [markdown]
# ## Install Google Maps Libraries

# %%
# !pip install -U googlemaps
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40746 sha256=148a44d15a2b0ef4ae3304413a642c71bf614b34da1eb56656ac0822a9fc808f
#   Stored in directory: c:\users\asus\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\17\f8\79\999d5d37118fd35d7219ef57933eb9d09886c4c4503a800f84
# Successfully built googlemaps
# ...

# %% [markdown]
# ## Import Libraries

# %%
import requests
import googlemaps
import pandas as pd

# %% [markdown]
# ## API KEYS CREDENTIALS

# %%
api_key = 'AIzaSyAVdewc0xUH1sQYtS94bK6f4jXsH6S-jro'

# %% [markdown]
# ## GET GOOGLE MAPS OBJECT

# %%
## GET GOOGLE MAPS OBJECT
gmaps = googlemaps.Client(key=api_key)

# %% [markdown]
# ## DATA PROCESSING

# %% [markdown]
# ### Get Places ID

# %%
df_places = pd.read_excel('indonesia_tourism (3).xlsx', sheet_name="Sheet3")

# %%
places_id = []
for place in df_places.columns:
  try:
    place_json = gmaps.places(place)
    if place_json['results']:  # Check if there are results
      place_id = place_json['results'][0]['place_id']
      places_id.append(place_id)
  except (KeyError, IndexError):
    # Handle cases where 'results' key is missing or empty
    pass

# %%
places_data = []

# %% [markdown]
# ### Get The Review

# %%
max_reviews = 5
default_review = 'blank'
default_rating = 0

places_data = []

for place_id, place_name in zip(places_id, df_places.columns):
    place_json = gmaps.place(place_id=place_id)
    result = place_json.get('result', {})
    place_data = {'id': place_id, 'name': place_name, 'reviews': [], 'ratings': []}
    
    # Check if 'reviews' key exists and is non-empty
    if 'reviews' in result and len(result['reviews']) > 0:
        # Iterate over each review up to max_reviews
        for review in result['reviews'][:max_reviews]:
            text = review.get('text', default_review)
            rating = review.get('rating', default_rating)
            place_data['reviews'].append(text)
            place_data['ratings'].append(rating)
        
        # If there are fewer reviews than max_reviews, pad with default values
        while len(place_data['reviews']) < max_reviews:
            place_data['reviews'].append(default_review)
            place_data['ratings'].append(default_rating)
    else:
        # Handle case where there are no reviews
        place_data['reviews'] = [default_review] * max_reviews
        place_data['ratings'] = [default_rating] * max_reviews
    
    # Append the place_data dictionary after processing all reviews
    places_data.append(place_data)

# Example to print the results
for data in places_data:
    print(f"Place ID: {data['id']}")
    print(f"Name: {data['name']}")
    print(f"Reviews: {data['reviews']}")
    print(f"Ratings: {data['ratings']}")
    print("-" * 20)
# Out:
# Place ID: ChIJLbFk59L1aS4RyLzp4OHWKj0
# Name: Monumen Nasional
# ...

# %%
places_data
# for i, review in enumerate(places_data):
#     print(f"total reviews for {places_data}: {places_data[i][]}")
# Out:
# [{'id': 'ChIJLbFk59L1aS4RyLzp4OHWKj0',
#   'name': 'Monumen Nasional',
#   'reviews': ['We visited on Thursday, arrived at entrance at 15:00 but ticket to the top was sold out and the museum already closed. The employees were busy to get ready to go home. Day was just getting cooler to enjoy such a big park.\nGood exercise up and down stairs but not much to see honestly, very disappointing. Free shuttle bus is provided from/ to SW Gate (Patung Kuda).',
#    'Interesting place with a popular and local marketplace. It is close to other interesting points. To go inside the tower need to pay approximately 35,000 IDR / 2 USD.',
# ...

# %% [markdown]
# ## DATA STORAGE

# %%
dict_places = {key: "blank" for key in df_places.columns}

# %%
import pandas as pd

# Step 1: Convert places_data to a dictionary
dict_places = {place['name']: place['reviews'] for place in places_data}

# Define max_reviews if needed to pad reviews to this length
max_reviews = 5
default_review = 'blank'

# Step 2: Ensure all places have the same number of reviews
for place in dict_places:
    while len(dict_places[place]) < max_reviews:
        dict_places[place].append(default_review)

# Step 3: Create a DataFrame
# Initialize an empty dictionary to store data for the DataFrame
df_data = {place: [] for place in dict_places}

# Fill the DataFrame data
for i in range(max_reviews):
    for place in dict_places:
        df_data[place].append(dict_places[place][i])

# Convert the dictionary to a DataFrame
df_reviews = pd.DataFrame(df_data)

# Example to print the DataFrame
print(df_reviews)
# Out:
#                                     Monumen Nasional  \
# 0  We visited on Thursday, arrived at entrance at...
# 1  Interesting place with a popular and local mar...
# 2  👍:\n-Probably the most iconic monument in Jaka...
# 3  132m/433ft high. Completed in 1975. The flame ...
# 4  Really happy to be here and learn about Indone...
#
#                                             Kota Tua  \
# 0  if you're looking for this white building with...
# 1  Beautiful landmark to be explored! Go anytime ...
# 2  Great to see these old buildings, I hope resta...
# 3                                            Awesome
# 4  Historical places that still kept by region go...
#
#                                        Dunia Fantasi  \
# 0  Fun place to enjoy a holiday, many rides to pu...
# 1  One of the most popular amusement parks in Jak...
# 2  Ive been coming here since early 90s as a chil...
# 3  I love this place! It was some of the most fun...
# ...

# %%
df_reviews.to_excel('dtr_review.xlsx')
